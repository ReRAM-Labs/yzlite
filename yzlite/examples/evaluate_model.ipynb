# %% [markdown]
# # Model Evaluation API Examples
#
# This demonstrates how to use the [evaluate_model](https://github.com/ReRAM-Labs/yzlite/docs/python_api/operations/evaluate.html) API.
#
# Refer to the [Model Evaluation](https://github.com/ReRAM-Labs/yzlite/docs/guides/model_evaluation.html) guide for more details.
#
# __NOTES:__
# - Click here: [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yizhutech/yzlite/blob/master/yzlite/examples/evaluate_model.ipynb) to run this example interactively in your browser
# - Refer to the [Notebook Examples Guide](https://github.com/ReRAM-Labs/yzlite/docs/guides/notebook_examples_guide.html) for how to run this example locally in VSCode

# %% [markdown]
# ## Install YZLITE Python Package

# %%
# Install the YZLITE Python package (if necessary)
#!pip uninstall yizhu-yzlite -y
# !pip install --upgrade yizhu-yzlite
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: yizhu-yzlite in /Users/xingqiangchen/.local/lib/python3.10/site-packages (0.2.4)
# Collecting yizhu-yzlite
#   Downloading yizhu_yzlite-0.2.6-1763809518-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Requirement already satisfied: typer<1.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (0.20.0)
# Requirement already satisfied: pytest in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (9.0.1)
# Requirement already satisfied: gast==0.4.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (0.4.0)
# Requirement already satisfied: pytest-dependency in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (0.6.0)
# Requirement already satisfied: pytest-html-reporter in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (0.2.9)
# Requirement already satisfied: cmake in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (4.2.0)
# Requirement already satisfied: ninja in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (1.13.0)
# Requirement already satisfied: psutil in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (7.1.3)
# Requirement already satisfied: pyaml<22.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (21.10.1)
# Requirement already satisfied: tensorflow>2.7 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (2.13.1)
# Requirement already satisfied: tensorflow_probability>=0.12.2 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (0.25.0)
# Requirement already satisfied: tflite-support in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (0.1.0a1)
# Requirement already satisfied: protobuf==3.20.3 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (3.20.3)
# Requirement already satisfied: onnx in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (1.17.0)
# Requirement already satisfied: onnxruntime in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (1.23.2)
# Requirement already satisfied: numpy==1.23 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (1.23.0)
# Requirement already satisfied: scipy<2.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (1.13.1)
# Requirement already satisfied: matplotlib<4.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (3.10.7)
# Requirement already satisfied: tqdm<5.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (4.67.1)
# Requirement already satisfied: pillow in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (12.0.0)
# Requirement already satisfied: librosa<1.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (0.11.0)
# Requirement already satisfied: bincopy<18.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (17.14.5)
# Requirement already satisfied: pyserial<4.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (3.5)
# Requirement already satisfied: GPUtil<2.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (1.4.0)
# Requirement already satisfied: patool==1.12 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (1.12)
# Requirement already satisfied: prettytable<3.0,>=2.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (2.5.0)
# Requirement already satisfied: msgpack in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from yizhu-yzlite) (1.1.2)
# Requirement already satisfied: humanfriendly in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from bincopy<18.0->yizhu-yzlite) (10.0)
# Requirement already satisfied: argparse-addons>=0.4.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from bincopy<18.0->yizhu-yzlite) (0.12.0)
# Requirement already satisfied: pyelftools in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from bincopy<18.0->yizhu-yzlite) (0.32)
# Requirement already satisfied: audioread>=2.1.9 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from librosa<1.0->yizhu-yzlite) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from librosa<1.0->yizhu-yzlite) (0.62.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from librosa<1.0->yizhu-yzlite) (1.7.2)
# Requirement already satisfied: joblib>=1.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from librosa<1.0->yizhu-yzlite) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from librosa<1.0->yizhu-yzlite) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from librosa<1.0->yizhu-yzlite) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from librosa<1.0->yizhu-yzlite) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from librosa<1.0->yizhu-yzlite) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from librosa<1.0->yizhu-yzlite) (4.5.0)
# Requirement already satisfied: lazy_loader>=0.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from librosa<1.0->yizhu-yzlite) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from matplotlib<4.0->yizhu-yzlite) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from matplotlib<4.0->yizhu-yzlite) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from matplotlib<4.0->yizhu-yzlite) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from matplotlib<4.0->yizhu-yzlite) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from matplotlib<4.0->yizhu-yzlite) (25.0)
# Requirement already satisfied: pyparsing>=3 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from matplotlib<4.0->yizhu-yzlite) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from matplotlib<4.0->yizhu-yzlite) (2.9.0.post0)
# Requirement already satisfied: wcwidth in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from prettytable<3.0,>=2.0->yizhu-yzlite) (0.2.14)
# Requirement already satisfied: PyYAML in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from pyaml<22.0->yizhu-yzlite) (6.0.3)
# Requirement already satisfied: click>=8.0.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from typer<1.0->yizhu-yzlite) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from typer<1.0->yizhu-yzlite) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from typer<1.0->yizhu-yzlite) (14.2.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from numba>=0.51.0->librosa<1.0->yizhu-yzlite) (0.45.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from pooch>=1.1->librosa<1.0->yizhu-yzlite) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from pooch>=1.1->librosa<1.0->yizhu-yzlite) (2.32.5)
# Requirement already satisfied: six>=1.5 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4.0->yizhu-yzlite) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa<1.0->yizhu-yzlite) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa<1.0->yizhu-yzlite) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa<1.0->yizhu-yzlite) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa<1.0->yizhu-yzlite) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0->yizhu-yzlite) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0->yizhu-yzlite) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0->yizhu-yzlite) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from scikit-learn>=1.1.0->librosa<1.0->yizhu-yzlite) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa<1.0->yizhu-yzlite) (2.0.0)
# Requirement already satisfied: pycparser in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa<1.0->yizhu-yzlite) (2.23)
# Requirement already satisfied: tensorflow-macos==2.13.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow>2.7->yizhu-yzlite) (2.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (25.9.23)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (3.4.0)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniconda/base/envs/yzlite_test/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (80.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (1.74.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (2.13.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (2.43.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in /opt/homebrew/Caskroom/miniconda/base/envs/yzlite_test/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (0.45.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (2.0.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (3.3.1)
# Requirement already satisfied: cloudpickle>=1.3 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow_probability>=0.12.2->yizhu-yzlite) (3.1.2)
# Requirement already satisfied: dm-tree in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tensorflow_probability>=0.12.2->yizhu-yzlite) (0.1.9)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-macos==2.13.1->tensorflow>2.7->yizhu-yzlite) (3.0.3)
# Requirement already satisfied: attrs>=18.2.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from dm-tree->tensorflow_probability>=0.12.2->yizhu-yzlite) (25.4.0)
# Requirement already satisfied: coloredlogs in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from onnxruntime->yizhu-yzlite) (15.0.1)
# Requirement already satisfied: sympy in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from onnxruntime->yizhu-yzlite) (1.14.0)
# Requirement already satisfied: exceptiongroup>=1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from pytest->yizhu-yzlite) (1.2.2)
# Requirement already satisfied: iniconfig>=1.0.1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from pytest->yizhu-yzlite) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from pytest->yizhu-yzlite) (1.6.0)
# Requirement already satisfied: tomli>=1 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from pytest->yizhu-yzlite) (2.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from sympy->onnxruntime->yizhu-yzlite) (1.3.0)
# Requirement already satisfied: pybind11>=2.4 in /Users/xingqiangchen/.local/lib/python3.10/site-packages (from tflite-support->yizhu-yzlite) (3.0.1)
# Downloading yizhu_yzlite-0.2.6-1763809518-cp310-cp310-macosx_11_0_arm64.whl (14.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 4.9 MB/s  0:00:03m0:00:0100:01
# Installing collected packages: yizhu-yzlite
#   Attempting uninstall: yizhu-yzlite
#     Found existing installation: yizhu-yzlite 0.2.4
#     Uninstalling yizhu-yzlite-0.2.4:
#       Successfully uninstalled yizhu-yzlite-0.2.4
# Successfully installed yizhu-yzlite-0.2.6

# %% [markdown]
# ## Import Python Packages

# %%
# Import the necessary YZLITE APIs
from yzlite.core import evaluate_model

# %% [markdown]
# ## Example 1: Evaluate Classification .h5 Model
#
# The following example evaluates the [image_example1](https://github.com/ReRAM-Labs/yzlite/blob/master/yzlite/models/examples/image_example1.py) model
# using the `.h5` (i.e. non-quantized, float32 weights) model file.
# This is a "classification" model, i.e. given an input, the model predicts to which
# "class" the input belongs.
#
# The [model archive](https://github.com/ReRAM-Labs/yzlite/docs/guides/model_archive.html) is updated with the evaluation results.
# Additionally, the `show` option displays interactive diagrams.

# %%
# Evaluate the .h5 image_example1 model and display the results
evaluation_results = evaluate_model('image_example1', show=True)
print(f'{evaluation_results}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Evaluate the .h5 image_example1 model and display the results
# ----> 2 evaluation_results = evaluate_model('image_example1', show=True)
#       3 print(f'{evaluation_results}')
#
# File ~/.local/lib/python3.10/site-packages/yzlite/core/evaluate_model.py:94, in evaluate_model(model, tflite, weights, max_samples_per_class, classes, dump, show, verbose, callbacks, update_archive, test, post_process)
#      89     if model.endswith(('.tflite', '.h5')):
#      90         raise ValueError(
#      91             'Must provide name of YZLITE model, '
#      92             'path to model archive (.yzlite.zip) or model specification script(.py)'
#      93         )
# ---> 94     yzlite_model = load_yzlite_model(model, test=test)
#      95 else:
#      96     raise ValueError(
#      97         'Must provide YZLiteModel instance, name of YZLITE model, path to '
#      98         'model archive (.yzlite.zip) or model specification script(.py)'
#      99     )
#
# File ~/.local/lib/python3.10/site-packages/yzlite/core/model/model_utils.py:89, in load_yzlite_model(model, test, print_not_found_err, logger, reload)
#      85 if not model_spec_path:
#      86     raise Exception(
#      87         f'Failed to find model specification file with name: {model}.py')
# ---> 89 return load_yzlite_model_with_path(
#      90     model_path=model_spec_path,
#      91     test=test,
#      92     logger=logger
#      93 )
#
# File ~/.local/lib/python3.10/site-packages/yzlite/core/model/model_utils.py:140, in load_yzlite_model_with_path(model_path, test, logger, reload)
#     138 try:
#     139     logger.debug(f'Importing {model_spec_path}')
# --> 140     model_module = import_module_at_path(model_spec_path, reload=reload)
#     141 except Exception as e:
#     142     prepend_exception_msg(
#     143         e, f'Failed to import YZLITE model module: {model_spec_path}')
#
# File ~/.local/lib/python3.10/site-packages/yzlite/utils/python.py:359, in import_module_at_path(path, reload)
#     356         return sys.modules[module_name]
#     358 # Otherwise import the module
# --> 359 return importlib.import_module(module_name, package=module_package)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/yzlite_test/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:992, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:992, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
#     [... skipping similar frames: _find_and_load at line 1027 (2 times), _gcd_import at line 1050 (2 times), _call_with_frames_removed at line 241 (1 times), _find_and_load_unlocked at line 992 (1 times)]
#
# File <frozen importlib._bootstrap>:992, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'YZLITE'

# %% [markdown]
# ## Example 2: Evaluate Classification .tflite Model
#
# The following example evaluates the [image_example1](https://github.com/ReRAM-Labs/yzlite/blob/master/yzlite/models/examples/image_example1.py) model
# using the `.tflite` (i.e. quantized, int8 weights) model file.
# This is a "classification" model, i.e. given an input, the model predicts to which
# "class" the input belongs.
#
# The [model archive](https://github.com/ReRAM-Labs/yzlite/docs/guides/model_archive.html) is updated with the evaluation results.
# Additionally, the `show` option displays interactive diagrams.

# %%
# Evaluate the .tflite image_example1 model and display the results
evaluation_results = evaluate_model('image_example1', tflite=True, show=True)
print(f'{evaluation_results}')

# %% [markdown]
# ## Example 3: Evaluate Auto-Encoder .h5 Model
#
# The following example evaluates the [anomaly_detection](https://github.com/ReRAM-Labs/yzlite/blob/master/yzlite/models/tinyml/anomaly_detection.py) model
# using the `.h5` (i.e. non-quantized, float32 weights) model file.
# This is an "auto-encoder" model, i.e. given an input, the model attempts to reconstruct
# the same input. The worse the reconstruction, the further the input is from what the
# model was trained against, this indicates that an anomaly may be detected.
#
# The [model archive](https://github.com/ReRAM-Labs/yzlite/docs/guides/model_archive.html) is updated with the evaluation results.
# Additionally, the `show` option displays interactive diagrams and the `dump`
# option dumps a comparison image between the input and reconstructed image.

# %%
# Evaluate the .h5 anomaly_detection model and display the results
evaluation_results = evaluate_model('anomaly_detection', show=True, dump=True)
print(f'{evaluation_results}')
